# %%
cd ~/thesis
ls -lh Untitled2.ipynb
# Out:
#   Cell In[1], line 1
#     cd ~/thesis
#        ^
# SyntaxError: invalid syntax

# %%
grep -RIn "3\.29|3\.64|rigidity|min_GV|max_GV" Untitled2.ipynb
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_1631/2357413897.py:1: SyntaxWarning: invalid escape sequence '\.'
#   grep -RIn "3\.29|3\.64|rigidity|min_GV|max_GV" Untitled2.ipynb
#   Cell In[2], line 1
#     grep -RIn "3\.29|3\.64|rigidity|min_GV|max_GV" Untitled2.ipynb
#               ^
# SyntaxError: invalid syntax
