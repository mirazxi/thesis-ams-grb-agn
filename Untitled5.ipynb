# %%
pip install -U nbstripout
nbstripout notebooks/*.ipynb
git add notebooks/*.ipynb
git commit -m "Strip notebook outputs for privacy"
git push
# Out:
#   Cell In[1], line 1
#     pip install -U nbstripout
#         ^
# SyntaxError: invalid syntax
