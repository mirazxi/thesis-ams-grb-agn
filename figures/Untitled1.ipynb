# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
mpl.rcParams.update({
    "font.size": 12,
    "axes.labelsize": 12,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11,
    "axes.titlesize": 12,
    "lines.linewidth": 1.2,
})

plt.figure(figsize=(12, 3.6))  # wider, journal-friendly aspect
# ... your plot / errorbar ...

plt.xlabel("Year")  # or "Date" if you prefer
plt.ylabel(r"Proton flux [$\mathrm{m^{-2}\,sr^{-1}\,s^{-1}\,GV^{-1}}$]")

# REMOVE the hard-coded title:
# plt.title(f"AMS-02 Proton Flux vs Time ({rmin}-{rmax} GV)")

# Optional: cleaner time axis
import matplotlib.dates as mdates
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator(1))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))

plt.tight_layout()
plt.savefig(out, dpi=300, bbox_inches="tight")

print("Saved:", out)
plt.show()
# Out:
# Saved: /home/david/thesis/figures/Fig05_CR_proton_flux_time_3p29_3p64GV.png
